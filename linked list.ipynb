# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None


def printll(head):
    cur=head
    while cur!=None:
        print(str(cur.data)+"->",end="")
        cur=cur.next
    print("None")
    return


 # tc n^2   
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head=None
    for ele in inputlist:
        newnode=node(ele)
        if head==None:
            head=newnode
        else:
            cur=head
            while cur.next!=None:
                cur=cur.next
            cur.next=newnode
    return head

# tc (n)
def takeinputoptimised():
    inputlist=[int(ele) for ele in input().split()]
    head=None
    for ele in inputlist:
        newnode=node(ele)
        if head==None:
            head=newnode
            tail=head
        else:
            newnode=node(ele)
            tail.next=newnode
            tail=newnode
    return head
    

# o(n)
def insertati(head,i,data):
    cur=head
    count=0
    while cur!=None:
        count+=1
        cur=cur.next

    if 0<=i<=count:
        cur=head
        count=0
        pre=None
        while count<i:
            pre=cur
            cur=cur.next
            count+=1
        newnode=node(data)
        
        if pre!=None:
            pre.next=newnode
        else:
            head=newnode
        newnode.next=cur
        return head     
    else:
        return head

# o(i)
def insertatir(head,i,data):
    # when given i is negative.
    if i<0:
        return head
    if i==0:
        newnode=node(data)
        newnode.next=head
        return newnode

    # when i is greater then length of linked list.
    if head==None:
        return None
    smallhead=insertatir(head.next,i-1,data)
    head.next=smallhead
    return head


def deleteati(head,i):
    if head==None:
        return None
    if head.next==None and i==0:
        return None
    if i==0:
        return head.next
    
    else:
        cur=head
        count=0
        while count<i-1:
            cur=cur.next
            count+=1
        cur.next=cur.next.next
        return head
    
def deleteatir(head,i):
    if i<0:
        return head
    if i==0:
        return head.next
    if head==None:
        return None
    smallhead=deleteatir(head.next,i-1)
    head.next=smallhead
    return head 


def findvalue(head,value):
    cur=head
    index=0
    while(cur!=None):
        if cur.data==value:
            print(index)
            break
        else:
            index+=1
            cur=cur.next
    else:
        print("-1")

# append n last node to first
def lastn(head,n):
    if head==None:
        return None
    cur=head
    length=0
    while cur!=None:
        pre=cur
        cur=cur.next
        length+=1
    length=length-n
    if length==0:
        return head
    cur=head
    count=1
    while count<length:
        cur=cur.next
        count+=1
    pre.next=head
    head=cur.next
    cur.next=None
    return head   


# remove duplicate in sorting linked list
def removeduplicate(head):
    if head==None:
        return None
    else:
        cur=head
        while(cur.next!=None):
            if cur.data==cur.next.data:
                if cur.next.next!=None:
                    cur.next=cur.next.next
                else:
                    cur.next=None
            else:
                cur=cur.next
        return head


# method 2
def removeduplicate1(head):
    t1=head
    t2=head.next
    while(t2!=None):
        if t1.data==t2.data:
            t2=t2.next
        else:
            t1.next=t2
            t1=t2
            t2=t2.next
    t1.next=t2
    return head




# print linked list in reverse order
def printrev(head):
    if head==None:
        return
    printrev(head.next)
    print(str(head.data)+"->",end="")

    
# make copy of ll in revsere order    
def makerevlist(head):
    cur=head 
    pre=None
    while(cur):
        newnode=node(cur.data)
        newnode.next=pre
        pre=newnode
        cur=cur.next
    return newnode



# change the original ll into reverse ll in (N^2)
def reverse(head):
    if head is None or head.next is None :
        return head
    smallhead=reverse(head.next)
    cur=smallhead
    while(smallhead.next):
        smallhead=smallhead.next
    smallhead.next=head
    head.next=None
    return cur


# change the original ll into reverse ll in (N)
def reverse1(head):
    if head is None or head.next is None :
        return head,head
    smallhead,tail=reverse1(head.next)
    tail.next=head
    head.next=None
    tail=head
    return smallhead,tail


# change the original ll into reverse ll in (N) better version
def reverse2(head):
    if head is None or head.next is None :
        return head
    smallhead=reverse2(head.next)
    tail=head.next
    tail.next=head
    head.next=None
    return smallhead


# change the original ll into reverse ll in (N) without recursion
def reverse3(head):
    cur=head
    pre=None
    while(cur):
        next=cur.next
        cur.next=pre
        pre=cur
        cur=next
    return pre  
    

def checkpalindrome(head):
    head1=makerevlist(head)
    cur=head
    cur1=head1
    while(cur!=None):
        if cur.data!=cur1.data:
            return False
        cur=cur.next
        cur1=cur1.next
    return True
    

# mid point of linked list
def midpoint(head):
    slow=head
    fast=head
    while(fast.next is not None and fast.next.next!=None):
        slow=slow.next
        fast=fast.next.next
    print(slow.data)



    
# merge two sorted ll
def mergetwoll(head1,head2):
    fh=None
    if head1==None:
        return head2
    if head2==None:
        return head1
    
    while(head1 and head2):
        if head1.data<=head2.data:
            if fh!=None:
                fh.next=head1
                fh=fh.next
            else:
                fh=head1
                final=fh
            head1=head1.next
        else:
            if fh!=None:
                fh.next=head2
                fh=fh.next
            else:
                fh=head2
                final=fh
            head2=head2.next
    if head1!=None and fh!=None:
        fh.next=head1
    if head2!=None and fh!=None:
        fh.next=head2
    return final



# delete n nodes after every m nodes **
def deletemn(head,m,n):
    t1=head
    while(True):
        count=1
        while(count<m):
            if t1.next==None:
                return head
            t1=t1.next
            count+=1
        t2=t1.next
        count=1
        if t2==None:
            return head
        while(count<n):
            if t2.next==None:
                t1.next=None
                return head
            t2=t2.next
            count+=1
        if t2.next is not None:
            t1.next=t2.next
        else:
            t1.next=None
            return head
        t1=t1.next


 
# swap data of two nodes

def swap(head,i1,i2):
    temp=head
    count=0
    while(temp):
        if count==i1:
            temp1=temp
            print(temp1.data)
        if count==i2:
            temp2=temp
            print(temp2.data)
        temp=temp.next
        count+=1
    temp1.data,temp2.data=temp2.data,temp1.data
    return head

# swap two nodes of linked list


# reverse every k nodes in linked list

    
# bubble sort using linkedlist

def bubblesort(head):
    temp=head
    l=0
    while(temp):
        temp=temp.next
        l+=1
    for i in range(l-1):
        l1=l-i-1
        temp=head
        while(l1):
            if temp.data>temp.next.data:
                temp.data,temp.next.data=temp.next.data,temp.data
                temp=temp.next
                l1=l1-1
    return head
    
    

head=takeinputoptimised()
head=bubblesort(head)
printll(head)
# Out:
# 1
# 1->None

# %% [markdown]
# Each element of linked list is called node.
