# %% [markdown]
# graph-> vertices,edges
# uses -> social media networks,road networks,
# connected graph-> path between any two vertices.
# connected component->connected subgraph of a graph
# less number of egdes ->adjcency list.
# more number of edges -> adcency matrix.
# has path pending
# tree is a graph which is connected and no cycle.
# mst-> n vertices and n-1 edges.
# kruskal algo-> take egdes with minimum weight and skip edge that form cycle.

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2]=1
        self.adjMatrix[v2][v1]=1

    def removeEdge(self,v1,v2):
        if self.containsEdge(v1,v2):
            self.adjMatrix[v1][v2]=0
            self.adjMatrix[v2][v1]=0

    def containsEdge(self,v1,v2):
        return True if self.adjMatric[v1,v2]>0 else False

    def dfsHelper(self,sv,visited):
        visited[sv]= True
        print(sv)
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i]>0 and visited[i]==False:
                self.dfsHelper(i,visited)


    def dfs(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i]==False:
                self.dfsHelper(i,visited)


    def bfsHelper(self,sv,visited):
        q=queue.Queue()
        q.put(sv)
        visited[0]=True
        while(not q.empty()):
            sv=q.get()
            print(sv)
            for i in range(self.nVertices):
                if self.adjMatrix[sv][i]>0 and visited[i]==False:
                    q.put(i)
                    visited[i]=True

    def bfs(self):
        visited=[False for i in range(self.nVertices)]
        for i in range(self.nVertices):
            if visited[i]==False:
                self.bfsHelper(i,visited)

    def __str__(self):
        return str(self.adjMatrix)
    
    

# nvertices error

# %%
g=Graph(8)
g.addEdge(0,1)
g.addEdge(1,3)
g.addEdge(2,4)
g.addEdge(2,3)
g.addEdge(0,2)
g.addEdge(6,7)

g.dfs()
print("bfs")
# g.bfs()
# Out:
# 0
# 1
# 3
# 2
# 4
# 5
# 6
# 7
# bfs

# %%
class Edge:
    def __init__(self,src,dest,wt):
        self.src=src
        self.dest=dest
        self.wt=wt

li=[int(e) for e in input().split()]
n=li[0]
E=li[1]

edges=[]

def kruskal(edges,nVertices):
    parent=[i for i in range(nVertices)]
    edges=sorted(edges,key=lambda edge:edge.wt)
    count=0
    i=0
    output=[]

    def getParent(v,parent):
        if parent[v]==v:
            return v
        else:
            return getParent(parent[v],parent)

    while count< nVertices-1:
        curr_edge=edges[i]
        srcParent=getParent(curr_edge.src,parent)
        destParent=getParent(curr_edge.dest,parent)
        if srcParent!=destParent:
            output.append(curr_edge)
            count+=1
            parent[srcParent]=destParent
        i+=1
    return output


for i in range(E):
    curr_input=[int(e) for e in input().split()]
    src=curr_input[0]
    dest=curr_input[1]
    wt=curr_input[2]
    edge=Edge(src,dest,wt)
    edges.append(edge)

output=kruskal(edges,n)


for edge in output:
    if edge.src<edge.dest:
        print(str(edge.src)+" "+str(edge.dest)+" "+str(edge.wt))
    else:
        print(str(edge.dest)+" "+str(edge.src)+" "+str(edge.wt))
# Out:
# 0 1 2
# 1 3 3
# 0 2 5

# %%
#prim alogorithm
import sys


class Graph:
    def __init__(self,nVertices):
        self.nVertices=nVertices
        self.adjMatrix=[[0 for i in range(nVertices)] for j in range(nVertices)]

    def addEdge(self,v1,v2,wt):
        self.adjMatrix[v1][v2]=wt
        self.adjMatrix[v2][v1]=wt

    def getMinVertex(self,visited,weight):
        minVertex=-1
        for i in range(self.nVertices):
            if visited[i]==False and (minVertex==-1 or weight[i]<weight[minVertex]):
                minVertex=i
        return minVertex

    def prims(self):
        visited=[False for i in range(self.nVertices)]
        parent=[-1 for i in range(self.nVertices)]
        weight=[sys.maxsize for i in range(self.nVertices)]

        weight[0]=0
        for i in range(self.nVertices-1):
            minVertex=self.getMinVertex(visited,weight)
            visited[minVertex]=True

            for j in range(self.nVertices):
                if self.adjMatrix[minVertex][j]>0 and visited[j]==False:
                    if weight[j]>self.adjMatrix[minVertex][j]:
                        weight[j]=self.adjMatrix[minVertex][j]
                        parent[j]=minVertex

        for i in range(self.nVertices):
            if i <parent[i]:
                print(str(i)+" "+str(parent[i])+" " +str(weight[i]))
            else:
                print(str(parent[i])+" "+str(i)+" " +str(weight[i]))


li=[int(e) for e in input().split()]
n=li[0]
E=li[1]

g=Graph(n)

for i in range(E):
    curr_input=[int(e) for e in input().split()]
    g.addEdge(curr_input[0],curr_input[1],curr_input[2])
g.prims()
# Out:
# -1 0 0
# 0 1 3
# 1 2 1
# 0 3 5
